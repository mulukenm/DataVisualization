# %%
import pandas as pd
from zipfile import ZipFile, Path
import warnings
warnings.filterwarnings("ignore")

# with ZipFile("https://ncsesdata.nsf.gov/datadownload/index.html?survey=PSD2019&type=data") as myzip:
#     data = myzip.open("psd19Public")

# #Now, we can read in the data
# df = pd.read_sas(data)

# df.head()

# %%
import pandas as pd
import zipfile

df = pd.read_sas('../../Users/muluken/WorkingFiles/NSF_NCSES/Data/psd17Public/epsd17.sas7bdat', format='sas7bdat')
df.head()
# Out:
#   ACADADJF ACADADMN ACADNA ACADOTHP ACADPDOC ACADRCHF ACADTCHF ACADV ACCAR  \
# 0     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
# 1     b'N'     b'N'   b'N'     b'N'     b'N'     b'N'     b'Y'  b'L'  b'L'
# 2     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
# 3     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
# 4     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
#
#   ACCCEP  ... WRKGP WTRCHOC WTREASN WTREM WTRLIC WTROPPS WTROT WTRPERS WTRSKL  \
# 0   b'L'  ...  b'N'    b'N'    b'3'  b'N'   b'Y'    b'Y'  b'N'    b'Y'   b'Y'
# 1   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
# 2   b'L'  ...  b'Y'    b'N'    b'5'  b'Y'   b'N'    b'N'  b'N'    b'N'   b'N'
# 3   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
# 4   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
#
#    WTSURVY
# 0  28.7080
# 1  12.0129
# 2   4.2133
# 3  10.9367
# 4   7.7709
#
# [5 rows x 241 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       ACADADJF ACADADMN ACADNA ACADOTHP ACADPDOC ACADRCHF ACADTCHF ACADV  \
# 0         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 1         b'N'     b'N'   b'N'     b'N'     b'N'     b'N'     b'Y'  b'L'
# 2         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 3         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 4         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# ...        ...      ...    ...      ...      ...      ...      ...   ...
# 85734     b'N'     b'N'   b'N'     b'N'     b'N'     b'Y'     b'Y'  b'L'
# 85735     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 85736     b'N'     b'N'   b'N'     b'N'     b'N'     b'N'     b'Y'  b'L'
# 85737     b'N'     b'Y'   b'N'     b'N'     b'N'     b'N'     b'N'  b'L'
# 85738     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
#
#       ACCAR ACCCEP  ... WRKGP WTRCHOC WTREASN WTREM WTRLIC WTROPPS WTROT  \
# 0      b'L'   b'L'  ...  b'N'    b'N'    b'3'  b'N'   b'Y'    b'Y'  b'N'
# 1      b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 2      b'L'   b'L'  ...  b'Y'    b'N'    b'5'  b'Y'   b'N'    b'N'  b'N'
# 3      b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 4      b'L'   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# ...     ...    ...  ...   ...     ...     ...   ...    ...     ...   ...
# 85734  b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 85735  b'L'   b'L'  ...  b'Y'    b'N'    b'5'  b'Y'   b'N'    b'N'  b'N'
# 85736  b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 85737  b'L'   b'L'  ...  b'Y'    b'N'    b'1'  b'N'   b'N'    b'N'  b'N'
# 85738  b'L'   b'L'  ...  b'N'    b'N'    b'1'  b'N'   b'N'    b'N'  b'N'
#
#       WTRPERS WTRSKL  WTSURVY
# 0        b'Y'   b'Y'  28.7080
# 1        b'L'   b'L'  12.0129
# 2        b'N'   b'N'   4.2133
# 3        b'L'   b'L'  10.9367
# 4        b'L'   b'L'   7.7709
# ...       ...    ...      ...
# 85734    b'L'   b'L'   3.7550
# 85735    b'N'   b'Y'   1.6724
# 85736    b'L'   b'L'   5.2166
# 85737    b'Y'   b'Y'   1.1077
# 85738    b'N'   b'Y'   1.1583
#
# [85739 rows x 241 columns]>
