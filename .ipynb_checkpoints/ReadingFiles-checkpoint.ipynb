# %%
import pandas as pd
from zipfile import ZipFile, Path


# with ZipFile("https://ncsesdata.nsf.gov/datadownload/index.html?survey=PSD2019&type=data") as myzip:
#     data = myzip.open("psd19Public")

# #Now, we can read in the data
# df = pd.read_sas(data)

# df.head()

# %%
import pandas as pd
import zipfile


df = pd.read_sas('C:/Users/Muluken/Other/Downloads/psd19Public/epsd19.sas7bdat', format='sas7bdat')
df.head()
# Out:
#   ACADADJF ACADADMN ACADNA ACADOTHP ACADPDOC ACADRCHF ACADTCHF ACADV ACCAR  \
# 0     b'N'     b'N'   b'N'     b'N'     b'N'     b'N'     b'Y'  b'L'  b'L'
# 1     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
# 2     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
# 3     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
# 4     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'  b'L'
#
#   ACCCEP  ... WRKGP WTRCHOC WTREASN WTREM WTRLIC WTROPPS WTROT WTRPERS WTRSKL  \
# 0   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
# 1   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
# 2   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
# 3   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
# 4   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'    b'L'   b'L'
#
#    WTSURVY
# 0  15.9323
# 1   4.6138
# 2  14.3837
# 3  10.5641
# 4  21.6238
#
# [5 rows x 240 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       ACADADJF ACADADMN ACADNA ACADOTHP ACADPDOC ACADRCHF ACADTCHF ACADV  \
# 0         b'N'     b'N'   b'N'     b'N'     b'N'     b'N'     b'Y'  b'L'
# 1         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 2         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 3         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 4         b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# ...        ...      ...    ...      ...      ...      ...      ...   ...
# 80877     b'N'     b'N'   b'N'     b'N'     b'N'     b'Y'     b'Y'  b'L'
# 80878     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 80879     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 80880     b'L'     b'L'   b'L'     b'L'     b'L'     b'L'     b'L'  b'L'
# 80881     b'N'     b'Y'   b'N'     b'N'     b'N'     b'N'     b'N'  b'L'
#
#       ACCAR ACCCEP  ... WRKGP WTRCHOC WTREASN WTREM WTRLIC WTROPPS WTROT  \
# 0      b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 1      b'L'   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 2      b'L'   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 3      b'L'   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 4      b'L'   b'L'  ...  b'N'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# ...     ...    ...  ...   ...     ...     ...   ...    ...     ...   ...
# 80877  b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 80878  b'L'   b'L'  ...  b'N'    b'N'    b'5'  b'Y'   b'N'    b'N'  b'N'
# 80879  b'L'   b'L'  ...  b'Y'    b'N'    b'1'  b'N'   b'N'    b'N'  b'N'
# 80880  b'L'   b'L'  ...  b'Y'    b'L'    b'L'  b'L'   b'L'    b'L'  b'L'
# 80881  b'L'   b'L'  ...  b'Y'    b'Y'    b'1'  b'Y'   b'Y'    b'Y'  b'N'
#
#       WTRPERS WTRSKL  WTSURVY
# 0        b'L'   b'L'  15.9323
# 1        b'L'   b'L'   4.6138
# 2        b'L'   b'L'  14.3837
# 3        b'L'   b'L'  10.5641
# 4        b'L'   b'L'  21.6238
# ...       ...    ...      ...
# 80877    b'L'   b'L'   2.8209
# 80878    b'N'   b'N'   2.9329
# 80879    b'N'   b'Y'   4.7560
# 80880    b'L'   b'L'   1.7833
# 80881    b'Y'   b'Y'   2.4326
#
# [80882 rows x 240 columns]>
